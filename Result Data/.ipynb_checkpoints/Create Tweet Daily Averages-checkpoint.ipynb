# %%
import pandas as pd
import numpy as np
from datetime import datetime

# %%
tweet_gen = pd.read_csv('senti_general_covid_tweet_data.csv',parse_dates=['Datetime'])
tweet_ny_gen = pd.read_csv('senti_nyc_popular_tweet_data.csv',parse_dates=['Datetime'])
tweet_ny_covid = pd.read_csv('senti_nyc_covid_tweet_data.csv',parse_dates=['Datetime'])

tweet_gen = tweet_gen.drop(columns=['Unnamed: 0','Unnamed: 0.1']);
tweet_ny_gen = tweet_ny_gen.drop(columns=['Unnamed: 0','Unnamed: 0.1']);
tweet_ny_covid = tweet_ny_covid.drop(columns=['Unnamed: 0','Unnamed: 0.1']);

# %%
tweet_gen.head()
# Out:
#                    Datetime  \
# 0 2020-01-21 23:59:43+00:00
# 1 2020-01-21 23:59:41+00:00
# 2 2020-01-21 23:59:06+00:00
# 3 2020-01-21 23:58:27+00:00
# 4 2020-01-21 23:54:52+00:00
#
#                                                 Text  retweets  \
# 0  It would be interesting to see if the Wuhan co...        87
# 1  CBP Enacts ‘Enhanced Health Screening’ as Chin...        57
# 2  Chinese coronavirus may have been lurking in a...        23
# 3  CDC and WHO are learning more about this new c...        25
# 4  My take: China is doing a massive cover up & p...        23
#
#                                            cleanText  \
# 0  it would interesting see wuhan coronavirus bin...
# 1  cbp enacts ‘ enhanced health screening ’ chine...
# 2     chinese coronavirus may lurking animal decade
# 3  cdc who learning new coronavirus every day at ...
# 4  my take china massive cover practicing crimina...
#
#                                       spellCorrected senti sentiSC
# 0  it would interesting see wuhan coronavirus bin...   [4]     [4]
# 1  cup enacts a enhanced health screening a chine...   [4]     [4]
# 2      chinese coronavirus may lurking animal decade   [4]     [4]
# 3  cdc who learning new coronavirus every day at ...   [4]     [4]
# 4  my take china massive cover practicing crimina...   [0]     [0]

# %%
#first lets figure out if the spell correction actually makes a difference for the sentiment

tweet_gen['equal'] = np.where(tweet_gen['senti']==tweet_gen['sentiSC'],1,0)
print('result similarity for senti vs sentiSC %')
print(tweet_gen['equal'].sum()/len(tweet_gen))

# looks like it didn't make much of a difference at all
# Out:
# result similarity for senti vs sentiSC %
# 0.9753846153846154

# %%
tweet_gen.head()
# Out:
#                    Datetime  \
# 0 2020-01-21 23:59:43+00:00
# 1 2020-01-21 23:59:41+00:00
# 2 2020-01-21 23:59:06+00:00
# 3 2020-01-21 23:58:27+00:00
# 4 2020-01-21 23:54:52+00:00
#
#                                                 Text  retweets  \
# 0  It would be interesting to see if the Wuhan co...        87
# 1  CBP Enacts ‘Enhanced Health Screening’ as Chin...        57
# 2  Chinese coronavirus may have been lurking in a...        23
# 3  CDC and WHO are learning more about this new c...        25
# 4  My take: China is doing a massive cover up & p...        23
#
#                                            cleanText  \
# 0  it would interesting see wuhan coronavirus bin...
# 1  cbp enacts ‘ enhanced health screening ’ chine...
# 2     chinese coronavirus may lurking animal decade
# 3  cdc who learning new coronavirus every day at ...
# 4  my take china massive cover practicing crimina...
#
#                                       spellCorrected senti sentiSC  equal
# 0  it would interesting see wuhan coronavirus bin...   [4]     [4]      1
# 1  cup enacts a enhanced health screening a chine...   [4]     [4]      1
# 2      chinese coronavirus may lurking animal decade   [4]     [4]      1
# 3  cdc who learning new coronavirus every day at ...   [4]     [4]      1
# 4  my take china massive cover practicing crimina...   [0]     [0]      1

# %%
# changing the pos/neg scores to -1 or 1

def normalizeSentiment(score):
    if (score == "[4]"):
        return 1
    else: 
        return -1
    
tweet_gen['senti'] = tweet_gen['senti'].apply(lambda x : normalizeSentiment(x))
tweet_ny_gen['senti'] = tweet_ny_gen['senti'].apply(lambda x : normalizeSentiment(x))
tweet_ny_covid['senti'] = tweet_ny_covid['senti'].apply(lambda x : normalizeSentiment(x))

# %%
tweet_gen.head()
# Out:
#                    Datetime  \
# 0 2020-01-21 23:59:43+00:00
# 1 2020-01-21 23:59:41+00:00
# 2 2020-01-21 23:59:06+00:00
# 3 2020-01-21 23:58:27+00:00
# 4 2020-01-21 23:54:52+00:00
#
#                                                 Text  retweets  \
# 0  It would be interesting to see if the Wuhan co...        87
# 1  CBP Enacts ‘Enhanced Health Screening’ as Chin...        57
# 2  Chinese coronavirus may have been lurking in a...        23
# 3  CDC and WHO are learning more about this new c...        25
# 4  My take: China is doing a massive cover up & p...        23
#
#                                            cleanText  \
# 0  it would interesting see wuhan coronavirus bin...
# 1  cbp enacts ‘ enhanced health screening ’ chine...
# 2     chinese coronavirus may lurking animal decade
# 3  cdc who learning new coronavirus every day at ...
# 4  my take china massive cover practicing crimina...
#
#                                       spellCorrected  senti sentiSC  equal
# 0  it would interesting see wuhan coronavirus bin...      1     [4]      1
# 1  cup enacts a enhanced health screening a chine...      1     [4]      1
# 2      chinese coronavirus may lurking animal decade      1     [4]      1
# 3  cdc who learning new coronavirus every day at ...      1     [4]      1
# 4  my take china massive cover practicing crimina...     -1     [0]      1

# %%
# let's also make a "weighted" column that multiplies by the number of retweets
tweet_gen['weightedSenti'] = tweet_gen['senti'].multiply(tweet_gen['retweets'])
tweet_ny_gen['weightedSenti'] = tweet_ny_gen['senti'].multiply(tweet_ny_gen['retweets'])
tweet_ny_covid['weightedSenti'] = tweet_ny_covid['senti'].multiply(tweet_ny_covid['retweets'])

# %%
# and a rolling sum column, which we will also weight
tweet_gen['rolling_sum'] = tweet_gen['senti'].rolling(3).sum()
tweet_gen['rolling_sum_weighted'] = tweet_gen['weightedSenti'].rolling(3).sum()

tweet_ny_gen['rolling_sum'] = tweet_ny_gen['senti'].rolling(3).sum()
tweet_ny_gen['rolling_sum_weighted'] = tweet_ny_gen['weightedSenti'].rolling(3).sum()

tweet_ny_covid['rolling_sum'] = tweet_ny_covid['senti'].rolling(3).sum()
tweet_ny_covid['rolling_sum_weighted'] = tweet_ny_covid['weightedSenti'].rolling(3).sum()

# %%
tweet_gen.head()
# Out:
#                    Datetime  \
# 0 2020-01-21 23:59:43+00:00
# 1 2020-01-21 23:59:41+00:00
# 2 2020-01-21 23:59:06+00:00
# 3 2020-01-21 23:58:27+00:00
# 4 2020-01-21 23:54:52+00:00
#
#                                                 Text  retweets  \
# 0  It would be interesting to see if the Wuhan co...        87
# 1  CBP Enacts ‘Enhanced Health Screening’ as Chin...        57
# 2  Chinese coronavirus may have been lurking in a...        23
# 3  CDC and WHO are learning more about this new c...        25
# 4  My take: China is doing a massive cover up & p...        23
#
#                                            cleanText  \
# 0  it would interesting see wuhan coronavirus bin...
# 1  cbp enacts ‘ enhanced health screening ’ chine...
# 2     chinese coronavirus may lurking animal decade
# 3  cdc who learning new coronavirus every day at ...
# 4  my take china massive cover practicing crimina...
#
#                                       spellCorrected  senti sentiSC  equal  \
# 0  it would interesting see wuhan coronavirus bin...      1     [4]      1
# 1  cup enacts a enhanced health screening a chine...      1     [4]      1
# 2      chinese coronavirus may lurking animal decade      1     [4]      1
# 3  cdc who learning new coronavirus every day at ...      1     [4]      1
# 4  my take china massive cover practicing crimina...     -1     [0]      1
#
#    weightedSenti  rolling_sum  rolling_sum_weighted
# 0             87          NaN                   NaN
# 1             57          NaN                   NaN
# 2             23          3.0                 167.0
# 3             25          3.0                 105.0
# 4            -23          1.0                  25.0

# %%
# should now try to get daily averages 

def dailyAverage(df):
    df = df.drop(columns=['Text','cleanText','retweets','spellCorrected','sentiSC','equal'])
    df.Datetime = pd.to_datetime(df.Datetime,errors='coerce')
    #df['Datetime'] = df['Datetime'].dt.date
    print(type(df['Datetime'][1]))
    df.resample('D').mean()
    return df
    
tDaily_gen = dailyAverage(tweet_gen)

tDaily_gen.head()
# Out:
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-142-136c5d240231> in <module>
#       9     return df
#      10
# ---> 11 tDaily_gen = dailyAverage(tweet_gen)
#      12
#      13 tDaily_gen.head()
#
# <ipython-input-142-136c5d240231> in dailyAverage(df)
#       6     #df['Datetime'] = df['Datetime'].dt.date
#       7     print(type(df['Datetime'][1]))
# ----> 8     df['Datetime'].resample('D').mean()
#       9     return df
#      10
#
# /usr/local/lib/python3.7/site-packages/pandas/core/generic.py in resample(self, rule, axis, closed, label, convention, kind, loffset, base, on, level)
#    8113             base=base,
#    8114             key=on,
# -> 8115             level=level,
#    8116         )
#    8117
#
# /usr/local/lib/python3.7/site-packages/pandas/core/resample.py in resample(obj, kind, **kwds)
#    1268     """
#    1269     tg = TimeGrouper(**kwds)
# -> 1270     return tg._get_resampler(obj, kind=kind)
#    1271
#    1272
#
# /usr/local/lib/python3.7/site-packages/pandas/core/resample.py in _get_resampler(self, obj, kind)
#    1402
#    1403         raise TypeError(
# -> 1404             "Only valid with DatetimeIndex, "
#    1405             "TimedeltaIndex or PeriodIndex, "
#    1406             f"but got an instance of '{type(ax).__name__}'"
#
# TypeError: Only valid with DatetimeIndex, TimedeltaIndex or PeriodIndex, but got an instance of 'RangeIndex'

# %%
tDaily_gen.resample('D').mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-108-a4b1dd4ddfdc> in <module>
# ----> 1 tDaily_gen.resample('D').mean()
#
# /usr/local/lib/python3.7/site-packages/pandas/core/generic.py in resample(self, rule, axis, closed, label, convention, kind, loffset, base, on, level)
#    8113             base=base,
#    8114             key=on,
# -> 8115             level=level,
#    8116         )
#    8117
#
# /usr/local/lib/python3.7/site-packages/pandas/core/resample.py in resample(obj, kind, **kwds)
#    1268     """
#    1269     tg = TimeGrouper(**kwds)
# -> 1270     return tg._get_resampler(obj, kind=kind)
#    1271
#    1272
#
# /usr/local/lib/python3.7/site-packages/pandas/core/resample.py in _get_resampler(self, obj, kind)
#    1402
#    1403         raise TypeError(
# -> 1404             "Only valid with DatetimeIndex, "
#    1405             "TimedeltaIndex or PeriodIndex, "
#    1406             f"but got an instance of '{type(ax).__name__}'"
#
# TypeError: Only valid with DatetimeIndex, TimedeltaIndex or PeriodIndex, but got an instance of 'RangeIndex'
