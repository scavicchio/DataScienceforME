# %%
import pandas as pd
import numpy as np
import requests
from nytimesarticle import articleAPI

# %% [markdown]
# ### Get json file using NYT API request

# %% [markdown]
# #### NYT api only allows to request monthly article; therefore each request generate 10 articles for each month. eg: 20200121-20200221; In this notebook, time will be set as three month begining at 20200121 and ending at 20200421. Each request only generates 10 articles which is not diverse enough. To make articles more diverse, I request articles from different page. (similar to clicking load more)

# %%
# This cell gets articles for the three month on page 1
r1 = requests.get("http://api.nytimes.com/svc/search/v2/articlesearch.json?q=coronavirus&begin_date=20200121&end_date=20200221&page=1&sort=relevance&api-key=AqibNhzEzAQATyvE3x9UZJWOXLWP85tX")
article1 = r1.json()

r2 = requests.get("http://api.nytimes.com/svc/search/v2/articlesearch.json?q=coronavirus&begin_date=20200221&end_date=20200321&page=1&sort=relevance&api-key=AqibNhzEzAQATyvE3x9UZJWOXLWP85tX")
article2 = r2.json()

r3 = requests.get("http://api.nytimes.com/svc/search/v2/articlesearch.json?q=coronavirus&begin_date=20200321&end_date=20200421&page=1&sort=relevance&api-key=AqibNhzEzAQATyvE3x9UZJWOXLWP85tX")
article3 = r3.json()

r4 = requests.get("http://api.nytimes.com/svc/search/v2/articlesearch.json?q=coronavirus&begin_date=20200421&end_date=20200501&page=1&api-key=AqibNhzEzAQATyvE3x9UZJWOXLWP85tX")
article4 = r4.json()

# %%
article4 = parse_articles(article4)

# %%
# This cell gets articles for the three month on page 2 (click load more by 2 times)
r11 = requests.get("http://api.nytimes.com/svc/search/v2/articlesearch.json?q=coronavirus&begin_date=20200121&end_date=20200221&page=2&sort=relevance&api-key=AqibNhzEzAQATyvE3x9UZJWOXLWP85tX")
article11 = r11.json()

r22 = requests.get("http://api.nytimes.com/svc/search/v2/articlesearch.json?q=coronavirus&begin_date=20200221&end_date=20200321&page=2&sort=relevance&api-key=AqibNhzEzAQATyvE3x9UZJWOXLWP85tX")
article22 = r22.json()

r33 = requests.get("http://api.nytimes.com/svc/search/v2/articlesearch.json?q=coronavirus&begin_date=20200321&end_date=20200421&page=2&sort=relevance&api-key=AqibNhzEzAQATyvE3x9UZJWOXLWP85tX")
article33 = r33.json()

r44 = requests.get("http://api.nytimes.com/svc/search/v2/articlesearch.json?q=covid19&begin_date=20200421&end_date=20200501&page=2&api-key=AqibNhzEzAQATyvE3x9UZJWOXLWP85tX")
article44 = r44.json()

# %%
article44 = parse_articles(article44)

# %%
# This cell gets articles for the three month on page 3 (click load more by 3 times)
r111 = requests.get("http://api.nytimes.com/svc/search/v2/articlesearch.json?q=coronavirus&begin_date=20200121&end_date=20200221&page=5&sort=relevance&api-key=AqibNhzEzAQATyvE3x9UZJWOXLWP85tX")
article111 = r111.json()

r222 = requests.get("http://api.nytimes.com/svc/search/v2/articlesearch.json?q=coronavirus&begin_date=20200221&end_date=20200321&page=5&sort=relevance&api-key=AqibNhzEzAQATyvE3x9UZJWOXLWP85tX")
article222 = r222.json()

r333 = requests.get("http://api.nytimes.com/svc/search/v2/articlesearch.json?q=coronavirus&begin_date=20200321&end_date=20200421&page=5&sort=relevance&api-key=AqibNhzEzAQATyvE3x9UZJWOXLWP85tX")
article333 = r333.json()

r444 = requests.get("http://api.nytimes.com/svc/search/v2/articlesearch.json?q=coronavirus&begin_date=20200421&end_date=20200501&page=5&api-key=AqibNhzEzAQATyvE3x9UZJWOXLWP85tX")
article444 = r444.json()

# %%
article444 = parse_articles(article444)

# %%
r1111 = requests.get("http://api.nytimes.com/svc/search/v2/articlesearch.json?q=coronavirus&begin_date=20200121&end_date=20200221&page=3&sort=relevance&api-key=AqibNhzEzAQATyvE3x9UZJWOXLWP85tX")
article1111 = r1111.json()

r2222 = requests.get("http://api.nytimes.com/svc/search/v2/articlesearch.json?q=coronavirus&begin_date=20200221&end_date=20200321&page=3&sort=relevance&api-key=AqibNhzEzAQATyvE3x9UZJWOXLWP85tX")
article2222 = r2222.json()

r3333 = requests.get("http://api.nytimes.com/svc/search/v2/articlesearch.json?q=coronavirus&begin_date=20200321&end_date=20200421&page=3&sort=relevance&api-key=AqibNhzEzAQATyvE3x9UZJWOXLWP85tX")
article3333 = r3333.json()

r4444 = requests.get("http://api.nytimes.com/svc/search/v2/articlesearch.json?q=covid19&begin_date=20200421&end_date=20200501&page=3&api-key=AqibNhzEzAQATyvE3x9UZJWOXLWP85tX")
article4444 = r4444.json()

# %%
article4444 = parse_articles(article4444)

# %%
r11111 = requests.get("http://api.nytimes.com/svc/search/v2/articlesearch.json?q=coronavirus&begin_date=20200121&end_date=20200221&page=4&sort=relevance&api-key=AqibNhzEzAQATyvE3x9UZJWOXLWP85tX")
article11111 = r11111.json()

r22222 = requests.get("http://api.nytimes.com/svc/search/v2/articlesearch.json?q=coronavirus&begin_date=20200221&end_date=20200321&page=4&sort=relevance&api-key=AqibNhzEzAQATyvE3x9UZJWOXLWP85tX")
article22222 = r22222.json()

r33333 = requests.get("http://api.nytimes.com/svc/search/v2/articlesearch.json?q=coronavirus&begin_date=20200321&end_date=20200421&page=4&sort=relevance&api-key=AqibNhzEzAQATyvE3x9UZJWOXLWP85tX")
article33333 = r33333.json()

r44444 = requests.get("http://api.nytimes.com/svc/search/v2/articlesearch.json?q=coronavirus&begin_date=20200421&end_date=202005014&page=4&api-key=AqibNhzEzAQATyvE3x9UZJWOXLWP85tX")
article44444 = r44444.json()

# %%
article44444 = parse_articles(article44444)

# %% [markdown]
# r111111 = requests.get("http://api.nytimes.com/svc/search/v2/articlesearch.json?q=coronavirus&begin_date=20200121&end_date=20200221&page=6&sort=relevance&api-key=2WCFSb6GFArnrb10RQGSyBF3D5Wc1SbE")
# article111111 = r111111.json()
#
# r222222 = requests.get("http://api.nytimes.com/svc/search/v2/articlesearch.json?q=coronavirus&begin_date=20200221&end_date=20200321&page=6&sort=relevance&api-key=2WCFSb6GFArnrb10RQGSyBF3D5Wc1SbE")
# article222222 = r222222.json()
#
# r333333 = requests.get("http://api.nytimes.com/svc/search/v2/articlesearch.json?q=coronavirus&begin_date=20200321&end_date=20200421&page=6&sort=relevance&api-key=2WCFSb6GFArnrb10RQGSyBF3D5Wc1SbE")
# article333333 = r333333.json()
#
# r444444 = requests.get("http://api.nytimes.com/svc/search/v2/articlesearch.json?q=coronavirus&begin_date=20200421&end_date=20200521&page=6&sort=relevance&api-key=2WCFSb6GFArnrb10RQGSyBF3D5Wc1SbE")
# article444444 = r444444.json()

# %%
def parse_articles(articles):
    '''
    This function takes in a response to the NYT api and parses
    the articles into a list of dictionaries
  
    '''
    news = []
    for i in articles['response']['docs']:
        dic = {}
        dic['id'] = i['_id']
        if i['abstract'] is not None:
            dic['abstract'] = i['abstract']
        dic['headline'] = i['headline']['main']
        
        dic['lead_paragraph'] = i['lead_paragraph']
        dic['date'] = i['pub_date'][0:10] # cutting time of day.
        dic['section'] = i['section_name']
        dic['source'] = i['source']
        
        dic['url'] = i['web_url']
        dic['word_count'] = i['word_count']
        
        news.append(dic)
    return(news)

# %%
article3 = parse_articles(article3)
article2 = parse_articles(article2)
article1 = parse_articles(article1)

# %%
article33 = parse_articles(article33)
article22 = parse_articles(article22)
article11 = parse_articles(article11)

# %%
article333 = parse_articles(article333)
article222 = parse_articles(article222)
article111 = parse_articles(article111)

# %%
article3333 = parse_articles(article3333)
article2222 = parse_articles(article2222)
article1111 = parse_articles(article1111)

# %%
article33333 = parse_articles(article33333)
article22222 = parse_articles(article22222)
article11111 = parse_articles(article11111)









#article444444 = parse_articles(article444444)
#article333333 = parse_articles(article333333)
#article222222 = parse_articles(article222222)
#article111111 = parse_articles(article111111)

# %%
# put all dictionaries together in one
article = article1 + article2 + article3 + article4 + article44 + article33 + article22 + article11 + article111 + article222 + article333 + article444 + article1111 + article2222 + article3333 + article4444 + article11111 + article22222 + article33333 + article44444

# %%
article_df = pd.DataFrame(article)
article_df['date'] = pd.to_datetime(article_df['date'])

# %%
article_df = article_df.sort_values(by="date")

# %%
article_df
# Out:
#                                               abstract       date  \
# 86   There are now three suspected cases in the cit... 2020-02-03
# 168  The latest cases were 14 people who had been e... 2020-02-03
# 162  Despite quarantine sites on military bases and... 2020-02-04
# 123  Tuesday: An update on the outbreak. Also: The ... 2020-02-04
# 89   A two-week quarantine has left Masako Ishida a... 2020-02-05
# 85   A factory in western France has become an unli... 2020-02-06
# 83   With infections doubling every four days and m... 2020-02-06
# 166  There are no confirmed cases of coronavirus in... 2020-02-06
# 88   Evacuees taken to Australia’s Christmas Island... 2020-02-06
# 84   Dr. Li Wenliang issued a warning about a stran... 2020-02-06
# 82   The country is scrambling to prevent a larger ... 2020-02-07
# 80   The doctor, Li Wenliang, had been silenced by ... 2020-02-07
# 169  The virus outbreak has rattled the global econ... 2020-02-07
# ...

# %%
article.to_csv('C:/Users/eric/Desktop/EXCEL/nytDATA.csv')

# %%
article = article_df.reset_index().drop(columns = ['index'])
